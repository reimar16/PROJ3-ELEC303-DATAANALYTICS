# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
dengue = pd.read_csv('dengue\\dengue.csv')

# %%
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   object
#  1   Year           1020 non-null   int64
#  2   Region         1020 non-null   object
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 40.0+ KB

# %%
dengue.dtypes
# Out:
# Month            object
# Year              int64
# Region           object
# Dengue_Cases      int64
# Dengue_Deaths     int64
# dtype: object

# %%
dengue['Year'] = dengue['Year'].astype('int')

# %%
dengue.dtypes
# Out:
# Month            object
# Year              int64
# Region           object
# Dengue_Cases      int64
# Dengue_Deaths     int64
# dtype: object

# %% [markdown]
# <H1> INSIGHTS FOR DENGUE ANALYSIS </H1>

# %% [markdown]
# <HR>

# %% [markdown]
# <h1> MONTHLY CASES OF DENGUE FROM 2016-2020 </h1>

# %%
monthly_cases.unstack().plot(kind='bar', stacked=True)
plt.gcf().set_size_inches(12,8)
plt.show()

# %% [markdown]
# <H1>  INSIGHTS 1-3 </H1>
#
# <H2> 1. August has the highest number of dengue cases, showing a clear peak during the rainy season. </H2>
# <H2> 2. The fewest cases occur between April and May, suggesting that dengue cases drop during the dry months.</H2>
# <H2> 3. 2019 recorded the highest number of dengue cases overall, especially from July to September. </H2>

# %% [markdown]
# <HR>

# %% [markdown]
# <h1> ANALYSIS OF DENGUE CASES PER REGION </h1>

# %%
visual1 = sns.barplot(data=dengue, x='Region', y="Dengue_Cases")
plt.gcf().set_size_inches(19,10)
plt.show()

# %% [markdown]
# <H1>  INISGHTS 4-6 </H1>
#
# <H2> 4. Regions III, VI, and NCR also show a high number of cases, indicating that densely populated or urban areas may have higher risks.  </H2>
# <H2> 5. BARMM and CAR have the lowest dengue cases, suggesting fewer outbreaks in these regions. </H2>
# <H2> 6. Region IV-A has the highest number of dengue cases compared to other regions, showing it is one of the most affected areas. </H2>

# %% [markdown]
# <HR>

# %%
plt.figure(figsize=(10,6))
plt.plot(monthly_cases['Date'], monthly_cases['Dengue_Cases'], label='Actual')
plt.plot(monthly_cases['Date'], monthly_cases['Predicted_Cases'], label='Predicted', linestyle='--')
plt.legend()
plt.title('Linear Regression Forecast of Dengue Cases')
plt.xlabel('Date')
plt.ylabel('Cases')
plt.show()

# %% [markdown]
# <H1> INSIGHTS 7-10 </H1>
#
# <H2> 7. The graph shows that dengue cases had a big spike around 2019, which was the year with the most recorded cases. </H2>
# <H2> 8. After 2019, the number of cases dropped sharply, possibly due to better prevention efforts or environmental changes.</H2>
# <H2> 9. The predicted trend orange line shows a slight increase over time, meaning dengue cases might rise slowly in the coming years if no stronger measures are taken. </H2>
# <H2> 10. The model’s prediction is smoother than the actual data, showing that real dengue cases can fluctuate more because of weather, population, and health factors. </H2>

# %% [markdown]
# <HR>
